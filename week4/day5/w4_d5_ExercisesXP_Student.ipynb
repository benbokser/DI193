# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# ### Your answer
# > To-Do:
# Please write your full answer below using complete sentences and clear structure.

# %% [markdown]
# Loan Default Prediction
#
# Prediction Objective:
# The target variable in this case is "Defaulted"--a boolean variable recording whether or not a borrower defaulted on a loan.
#
# Data to Collect:
# To predict loan defaults, I would collect the following data: applicant age, net worth, salary, education level, job history, credit score, current loan amount, prior loan amounts, repayment history, and credit card repayment history. Applicant age can predict loan defaults because an older applicant may be likely to be more responsible. Net worth and salary can predict loan defaults because they indicate how much money the applicant is expected to have available to repay the loan. Education level and job history can predict loan defaults because they can indicate the applicant's level of responsibility and likelihood to have a good, stable job in the future. Credit score can predict loan defaults because it is a score designed to predict an applicant's likelihood to repay a loan. Corrent loan amounts, prior loan amounts and repayment history can help predict loan defaults because they represent past history of loan repayment behavior and the size of prior loans can be compared to the size of this loan to indicate how similar it may be. Credit card repayment history can predict loan defaults because it represents an applicant's history of making credit payments.
#
# Realistic Data Sources:
# Applicant age, net worth, salary, education level, job history, and current loan amount would be obtained from the user in the loan application and could be confirmed by checking with relevant third parties. Credit score would be obtained from a credit bureau, with the applicant's approval. Prior loan amounts and repayment history would be obtained from the financial institution's internal records, if loans were taken from the same institution, or from other institution's records, with the applicant's approval. Credit card repayment history would be obtained from the applicant's credit card provider(s), with the applicant's approval.
#
# Risks and Constraints:
# The data to be used here raises privacy concerns. It is fine to use this data to predict whether an applicant will default on a loan, as long as the data is kept secure and private (not on public platforms). If is used as part of a larger training set to train a prediction algorithm that is used afterwards, the data should be anonymized as much as possible and still kept securely. It is important to consider relevant regulations regarding data privacy and ownership (it may be necessary to receive a user's consent before using data to train a prediction engine). Regarding data quality, data that comes from a loan application can have inconsistent quality; efforts should be made to ensure the data is complete and fits required formats on the application. Having the application be online can encourage this. Regarding sampling bias, if training data on a prediction algorithm only comes from specific banks, it may be particular to those banks' clientele, which may have unique characteristics, and thus not fully applicable to all applicants. Regarding governance, the loan officer and personal banking clerk have primary governance over the applicant's data, while any analyst working on the project has primary governance over any models and algorithms created and must also be concerned with the data.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
# # example_columns = [
# #     "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
# #     "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
# #     "purpose","term","application_type","state","zip_code"
# # ]
# df = pd.DataFrame(columns=example_columns)
df = pd.read_csv('loan_predication.csv')
df.head()
# Please replace this list with the actual columns that you select.
# selected_features = [
#     # e.g., "credit_score","debt_to_income","annual_income","loan_amount","interest_rate",
#     # "employment_length","num_delinquencies","total_utilization"
# ]

# print("You will now justify the selected features in complete sentences below.")
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df['Education'].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %%
df.isna().mean()
# Out:
# Loan_ID              0.000000
# Gender               0.021173
# Married              0.004886
# Dependents           0.024430
# Education            0.000000
# Self_Employed        0.052117
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           0.035831
# Loan_Amount_Term     0.022801
# Credit_History       0.081433
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# ### Your justification
# > To-Do: Please write complete sentences that justify the relevance of each selected feature.
# If you excluded any common features, please state your reasons in complete sentences.
#
# Also explain, in two complete sentences, how you would encode categorical variables and how you would impute missing values.

# %% [markdown]
# Most Relevant Features:
# I believe the most relevant features are Education, ApplicantIncome, CoapplicantIncome, LoanAmount, Self_Employed, Loan_Amount_Term, and Credit_History. Education relates to the likelihood of default because an applicant with higher education is likely to be better at fulfilling commitments and likelier to have a more stable and good-paying job. ApplicantIncome can help predict loan default because it indicates how much money the applicant will have available to repay the loan. CoapplicantIncome is relevant for the same reason, as it represents the amount of money available to the coapplicant. LoanAmount is relevant because the higher the loan (compared to applicant and coapplicant income), the harder it may be to repay. Self_Employed is relevant because a self-employed person is likely to have higher income volatility which can make him more likely to default. Loan_Amount_Term is relevant because when there is a longer amount of time to repay the loan, it is easier to repay. Credit_History is clearly relevant because it indicates an applicant's prior history of repaying loans, which would generally predict his likelihood to repay future loans.
#
# I excluded Gender because I could not be sure it predicts default, and if it does predict default, it may do so as a proxy for other factors such as income and education. If so it is best to avoid. I excluded married and dependents because I could come up with arguments for them to predict default or repayment; they may not correlate well at all. I excluded Property_Area because I could not come up with clear reasons why it would be relevant, and its relevance may be mainly in its serving as a proxy for other features such as education and income.
# Self-Employed is a boolean, so I would impute it as a 0 or 1. Education only has two values, so it is like a boolean too, and I would impute it as a 0 or a 1. Regarding missing values, the features with over 5% missing values are Self_Employed and Credit_History. In these cases, Self_Employed is a categorical column, so I would impute the mode, and Credit_History is numerical, so I would impute the median.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))

# %% [markdown]
# ### Your answer
# > To-Do: Please write complete sentences that explain your model choice, your evaluation plan, your approach to class imbalance, and your threshold selection strategy.

# %% [markdown]
# Several models may be suitable for loan prediction. Logistic regression is suitable because it is fast to train and provides clear coefficients that explain why a loan was denied, which may be necessary for regulatory compliance. Random Forest is also suitable because it is hard to overfit and provides a feature importance ranking to show which variables matter most.
#
# Evaluation Plan:
# I would perform an initial data split of 80% of data in a training set and 20% in a hold-out test set. I would use a Stratified K-Fold Cross-Validation strategy to ensure that the proportion of defaults is consistent across every fold, to provide a stable estimate of model performance. Because the default rate is generally small but the cost of a default and thus the cost of a false negative (missing a default) is high, I would report recall, which measures the proportion of defaults identified, and F-1 score, because it also takes into account false positives, which are also costly, and is more informative than accuracy for impalanced data. To choose a decision threshold, I would perform a cost-benefit analysis on the validation set to find a threashold that minimizes the total financial loss caused by both missed defaults and rejected creditworthy applicants.
#
# Addressing Class Imbalance:
# Loan default data has class imbalance because loan defaults are generally rare. I would address this by first using stratification in all data splitting. I would apply class weights to influence the model's learning process. I could also use resampling techniques like random under-sampling of the majority class to balance the training distribution.
#
# Hyperparameter Iteration and Data Leakage:
# In order to iterate on hyperparameters to improve performance while avoiding data leakage, I would use Grid Search Search within the cross-validation loops to find the optimal configuration. To avoid data leakage, I would ensure that preprocessing steps such as scaling and resampling are performed within a pipeline so that parameters are calculated only on the training folds and never are exposed to validation or test data.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below, using full sentences for each scenario.

# %% [markdown]
# Predicting Stock Prices : predict future prices
# The appropriate ML paradigm for this scenario is supervised learning, because the target variable is set--future stock prices (or any day's increase/decrease). The input data would be the stock's price history (in previous days), its market capitalization, trading volume, PE ratio, and dividend. The output would be the upcoming closing stock price. The objective would be to successfully predict the upcoming closing stock price.
#
# Organizing a Library of Books : group books into genres or categories based on similarities. The appropriate ML paradigm for this scenario is unsupervised learning, because the genres or categories are not yet set; it is up to the model to classify them. The input data would be book name, length, IDs of users who purchased or lent out the book, average words per sentence, and average word length. (A more advanced model could use the book's entire text as input data too.) The output would be a genre or category for each book. The objective would be for each book to have more in common with books within its category than with books outside its category, primarily in terms of users who purchased or lent out the book.
#
# Program a robot to navigate and find the shortest path in a maze. The appropriate ML paradigm for this scenario is reinforcement learning, because the goal is not providing one answer or categorizing data, but providing an output that can be continuously improving. The input data would be the maze itself and the robot's current position in it. The output would be the robot's next move in the maze. The learning signal or objective would be, first, to reach the end of the maze, and second, to minimize the length of the moves made in the maze from start to end.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below as three paragraphs, one for supervised learning, one for unsupervised learning, and one for reinforcement learning.

# %% [markdown]
# For the supervised learning category, I will use Logistic Regression. My validation plan is to use a ROC curve (to visualize the trade-off between the true positive and false positive rates) and to focus on F1 score as a metric. A major challenge with this category is dealing with class imbalance. This can be addressed by using nuanced metrics like the F1 score.
#
#
# For the unsupervised learning category, I will use K-Means Clustering. To assess the effectiveness of the clusters, I will use the Elbow Method to find the optimal number of clusters (by plotting the within-cluster sum of squares and identifying the "elbow"point where the marginal gain in variance explanation diminishes. I will also calculate the Silhoutte Score to measure how similar an object is to its own cluster compared to other clusters, ensuring the groupings are well-separated and cohesive. The major challenge in this category is the lack of ground truth labels, which makes it difficult to objectively prove that discovered clusters represent meaningful categories rather than noise.
#
# For the reinforcement learning category, I will implement a Deep Q-Network (DQN). I will measure success by tracking cumulative reward over successive episodes, seeking a steady upward trend that indicates the agent is successfully learning the objective. To assess convergence, I will monitor the stability of the loss function and the consistency of total rewards, ensuring that the policy has stabilized and is no longer oscillating significantly. I will balance exploration and exploitation by using an epsilon-greedy strategy, where the probability of taking a random action gradually decays over time as the agent becomes more confident in its learned values. One major challenge in this category is the credit assignment problem, in which it is hard to determine which specific action in a long sequence was responsible for an outcome that eventually turned out successful or unsuccessful.
