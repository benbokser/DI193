# %%
# Exercise 1: Hello World
# Instructions

# Print the following output using one line of code:

# Hello world
# Hello world
# Hello world
# Hello world

print("Hello world\n"*4)
# Out:
# Hello world
# Hello world
# Hello world
# Hello world

# %%
# Exercise 2: Some Math
# Instructions

# Write code that calculates the result of:

# (99^3)*8 (meaning 99 to the power of 3, times 8).
print((99**3)*8)
# Out:
# 7762392

# %%
# Exercise 3: What is the output?
# Instructions

# Predict the output of the following code snippets:
# Coment what is your guess, then run the code and compare
5 < 3 #False
3 == 3 #True
3 == "3" #False
"3" > 3 #Error
"Hello" == "hello" #False
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       7 3 == 3 #True
#       8 3 == "3" #False
# ----> 9 "3" > 3 #Error
#      10 "Hello" == "hello" #False
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
# 🌟 Exercise 4: Your computer brand
# Instructions

#     Create a variable called computer_brand
# which value is the brand name of your computer.
#     Using the computer_brand variable,
# print a sentence that states the following:

# "I have a <computer_brand> computer."
computer_brand = "Lenovo"
print(f'I have a {computer_brand} computer.')
# Out:
# I have a Lenovo computer.

# %%
# 🌟 Exercise 5: Your information
# Instructions

#     Create a variable called name, and set it’s value to your name.
name = "Ben"
#     Create a variable called age, and set it’s value to your age.
age = 39
#     Create a variable called shoe_size, and set it’s value
#  to your shoe size.
shoe_size = 46
#     Create a variable called info and set it’s value to an interesting
#  sentence about yourself. The sentence must contain all the variables
#  created in parts 1, 2, and 3.
info = f'My name is {name}, I am {age} years old, and my feet are size {shoe_size}.'
#     Have your code print the info message.
print(info)
#     Run your code.
# Out:
# My name is Ben, I am 39 years old, and my feet are size 46.

# %%
# 🌟 Exercise 6: A & B
# Instructions

#     Create two variables, a and b.
#     Each variable’s value should be a number.
a = 10
b = 5
#     If a is bigger than b, have your code print "Hello World".
if a > b:
    print('Hello World')
# Out:
# Hello World

# %%
# Exercise 7: Odd or Even
# Instructions

# Write code that asks the user for a number and determines whether this number is odd or even.
num1 = int(input('Choose a number:'))
if num1 % 2 == 0:
    print('That is an even number.')
else:
    print('That is an odd number.')
# Out:
# That is an odd number.

# %%
# 🌟 Exercise 8: What’s your name?
# Instructions

# Write code that asks the user for their name and determines whether or not you have the same name.
#  Print out a funny message based on the outcome.
my_name = 'Ben'
user_name = input('What is your name?')
if user_name == my_name:
    print('We have the same name! We must be special.')
else:
    print('We have different names. I guess we are both unique.')
# Out:
# We have different names. I guess we are both unique.

# %%
# 🌟 Exercise 9: Tall enough to ride a roller coaster
# Instructions

#     Write code that will ask the user for their height in centimeters.
height = int(input('What is your height in cm?'))
#     If they are over 145 cm, print a message that states they are tall enough to ride.
#     If they are not tall enough, print a message that says they need to grow some more to ride.
if height > 145:
    print('You are tall enough to ride.')
else:
   print('You need to grow some more to ride.')
# Out:
# You need to grow some more to ride.
