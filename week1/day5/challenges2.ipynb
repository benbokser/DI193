# %%
# Exercise 1
# Instructions

#     Draw the following pattern using for loops:

#   *
#  ***
# *****

rows = 3

for i in range(1, rows + 1):
    # Calculate spaces: total rows minus current row index
    spaces = " " * (rows - i)
    
    # Calculate stars: 2 * current row minus 1
    stars = "*" * (2 * i - 1)
    
    # Combine and print
    print(spaces + stars)
# Out:
#   *
#  ***
# *****

# %%
#     Draw the following pattern using for loops:

#     * 4 spaces 1 star
#    ** 2 spaces 2 stars
#   *** 1 spaces 3 stars
#  **** 1 spaces 4 stars
# ***** 0 spaces 5 stars

for i in range(1,6):
    spaces = 5 - i
    stars = i
    print(' '*spaces + '*'*stars)
# Out:
#     *
#    **
#   ***
#  ****
# *****

# %%
#     Draw the following pattern using for loops:

# *
# **
# ***
# ****
# *****
# *****
#  ****
#   ***
#    **
#     *
for i in range(1,6):
    print('*'*i)
for i in range(6,11):
    stars = 11 - i
    spaces = i - 6
    print(' '*spaces + '*'*stars)
# Out:
# *
# **
# ***
# ****
# *****
# *****
#  ****
#   ***
#    **
#     *

# %%
# Exercise 2
# Instructions

#     Analyse this code before executing it. Write some commnts next to each line. Write the value of each variable and their changes, and add the final output. Try to understand the purpose of this program.

my_list = [2, 24, 12, 354, 233]
for i in range(len(my_list) - 1):
    minimum = i
    for j in range( i + 1, len(my_list)):
        if(my_list[j] < my_list[minimum]):
            minimum = j
            if(minimum != i):
                my_list[i], my_list[minimum] = my_list[minimum], my_list[i]
print(my_list)
# The purpose of the program is to sort the list from smallest to largest.
# Out:
# [2, 12, 24, 233, 354]
