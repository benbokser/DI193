# %%
# Exercise 1: Concatenate lists
# Instructions

# Write code that concatenates two lists together without using the + sign.
list1 = [1,2,3]
list2 = [4,5,6]
list3 = [*list1, *list2]
print(list3)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# Exercise 2: Range of numbers
# Instructions

# Create a loop that goes from 1500 to 2500 and prints all multiples of 5 and 7.
for i in range(1500,2501):
    if i%5 == 0 or i%7 == 0:
        print(i, end = ' ')
# Out:
# 1500 1505 1510 1512 1515 1519 1520 1525 1526 1530 1533 1535 1540 1545 1547 1550 1554 1555 1560 1561 1565 1568 1570 1575 1580 1582 1585 1589 1590 1595 1596 1600 1603 1605 1610 1615 1617 1620 1624 1625 1630 1631 1635 1638 1640 1645 1650 1652 1655 1659 1660 1665 1666 1670 1673 1675 1680 1685 1687 1690 1694 1695 1700 1701 1705 1708 1710 1715 1720 1722 1725 1729 1730 1735 1736 1740 1743 1745 1750 1755 1757 1760 1764 1765 1770 1771 1775 1778 1780 1785 1790 1792 1795 1799 1800 1805 1806 1810 1813 1815 1820 1825 1827 1830 1834 1835 1840 1841 1845 1848 1850 1855 1860 1862 1865 1869 1870 1875 1876 1880 1883 1885 1890 1895 1897 1900 1904 1905 1910 1911 1915 1918 1920 1925 1930 1932 1935 1939 1940 1945 1946 1950 1953 1955 1960 1965 1967 1970 1974 1975 1980 1981 1985 1988 1990 1995 2000 2002 2005 2009 2010 2015 2016 2020 2023 2025 2030 2035 2037 2040 2044 2045 2050 2051 2055 2058 2060 2065 2070 2072 2075 2079 2080 2085 2086 2090 2093 2095 2100 2105 2107 2110 2114 2115 2120 2121 2125 2128 2130 213
# ...

# %%
# Exercise 3: Check the index
# Instructions

# Using this variable

# names = ['Samus', 'Cortana', 'V', 'Link', 'Mario', 'Cortana', 'Samus']
names = ['Samus', 'Cortana', 'V', 'Link', 'Mario', 'Cortana', 'Samus']

# Ask a user for their name, if their name is in the names list print out the index of
# the first occurence of the name.

# Example: if input is 'Cortana' we should be printing the index 1
user_name = input('What is your name?')
if user_name in names:
    print(names.index(user_name))
# Out:
# 4

# %%
# Exercise 4: Greatest Number
# Instructions

# Ask the user for 3 numbers and print the greatest number.
num1 = int(input('Input the 1st number:'))
num2 = int(input('Input the 2nd number:'))
num3 = int(input('Input the 3rd number:'))
max_num = max([num1, num2, num3])
print(f'The greatest number is: {max_num}')
# Test Data
# Input the 1st number: 25
# Input the 2nd number: 78
# Input the 3rd number: 87

# The greatest number is: 87
# Out:
# The greatest number is: 6

# %%
# Exercise 5: The Alphabet
# Instructions

#     Create a string of all the letters in the alphabet
letters = 'abcdefghijklmnopqrstuvwxyz'
#     Loop over each letter and print a message that contains the letter and whether its a vowel or a consonant.
vowels = 'aeiou'
for i in letters:
    print(i)
    if i in vowels:
        print('vowel')
    else:
        print('consonant')
# Out:
# a
# vowel
# b
# consonant
# c
# consonant
# d
# consonant
# e
# vowel
# f
# consonant
# g
# consonant
# h
# consonant
# i
# vowel
# j
# consonant
# k
# consonant
# l
# consonant
# m
# consonant
# n
# consonant
# o
# vowel
# p
# consonant
# q
# consonant
# r
# consonant
# s
# consonant
# t
# consonant
# u
# vowel
# v
# consonant
# w
# consonant
# x
# consonant
# y
# consonant
# z
# consonant

# %%
# Exercise 6: Words and letters
# Instructions

#     Ask a user for 7 words, store them in a list named words.
words = input('Write 7 words separated by a space.').split()
#     Ask the user for a single character, store it in a variable called letter.
letter = input('Write a character.')
#     Loop through the words list and print the index of the first appearence of the letter variable 
# in each word of the list.
for word in words:
    if letter in word:
        print(word.index(letter))
    else: print(f'A friendly message. Word is {word}, letter is {letter}.')
#     If the letter doesn’t exist in one of the words, print a friendly message with the word and the letter.
# Out:
# A friendly message. Word is Write, letter is d.
# A friendly message. Word is seven, letter is d.
# 3
# 8
# A friendly message. Word is by, letter is d.
# A friendly message. Word is a, letter is d.
# A friendly message. Word is space, letter is d.

# %%
# Exercise 7: Min, Max, Sum
# Instructions

# Create a list of numbers from one to one million and then use min() and max()
# to make sure your list actually starts at one and ends at one million.
# Use the sum() function to see how quickly Python can add a million numbers.
list1 = range(1,1000001)
print(list1)
print(min(list1))
print(max(list1))
print(sum(list1))
# Out:
# range(1, 1000001)
# 1
# 1000000
# 500000500000

# %%
# Exercise 8 : List and Tuple
# Instructions

# Write a program which accepts a sequence of comma-separated numbers.
# Generate a list and a tuple which contain every number.
str = input('Write a sequence of comma-separated numbers.')
# Suppose the following input is supplied to the program: 34,67,55,33,12,98

# Then, the output should be:
list1 = str.split(',')
tuple1 =...
# ['34', '67', '55', '33', '12', '98']
# ('34', '67', '55', '33', '12', '98')
print(list1)
# Out:
# ['1', '2', '3']
